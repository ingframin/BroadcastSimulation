# %%
from math import e, factorial,log, gamma, sqrt, floor
from matplotlib import pyplot as pt
from numpy import linspace, correlate
from IPython.display import Markdown
from analysis import *

# %%
def genWindowHistogram(r1,r2,wnd,trx):
    windows = []
    for i in range(0,len(r1),wnd):
        count = 0
        for j in range(i,i+wnd):
            try:
                if r1[j]=='S' and r2[j]=='B':
                    count += 1
            except:
                pass
        windows.append(count)
     
    result = [0 for i in range(wnd)]
    for n in range(len(result)):
        result[n] = windows.count(n)/len(windows)
    
    return result

Ttx = 23
Trx = 60
Tn = 100
Tw = 1000
pt.rcParams["figure.figsize"] = (20,10)

# %% [markdown]
# ## Networking disabled

# %%
h1 = []
cmp = []
for i in range(1,10):
    f1 = open("r%d-d0-result.txt"%i)
    raw1 = f1.read()
    f1.close()

    f2 = open("r%d-d1-result.txt"%i)
    raw2 = f2.read()
    f2.close()
    
    Eb1,Es1,En1 = computeEvents(raw1,Ttx,Trx,Tn)
    Eb2,Es2,En2 = computeEvents(raw2,Ttx,Trx,Tn)
    
    wnds1 = genWindowHistogram(raw1,raw2,1000,Trx)
    Ps = checkSuccess(raw2,raw1)*Ttx/(Eb1*Ttx+En1*Tn+Es1*Trx)
    print("Success probability evts: %.6f"%(Ps))
    print('-----------------------------------------------------------')
    Ps1 = Es1*Trx/(Eb1*Ttx+En1*Tn+Es1*Trx)
    Pb2 = Eb2*Ttx/(Eb1*Ttx+En1*Tn+Es1*Trx)
    rt1 = Pb2/(Trx/1000)
    P0w = Pb2*(1-Ps1)+Ps1*(1-Pb2)+(1-Ps1)*(1-Pb2)
    print("P0w= %.6f;Hist[0]= %.6f"%(P0w,wnds1[0]))
    h1.append(wnds1[0])
    cmp.append(P0w)
    print("PB2= %.6f"%(Pb2))
    print("PS1= %.6f"%(Ps1))
    print("PB*PS= %.6f"%(Pb2*Ps1))
    print("rt1 = %.6f B/s"%(rt1))
    print("P(At least 1 beacon during Tw)= %.6f"%(1-wnds1[0]))
    print('-----------------------------------------------------------')
    
    pt.plot(range(len(wnds1)),wnds1,label=r"$P_{S}$= %.6f"%(Trx*Es1/len(raw1)))

print(correlate(h1,cmp))
print('-----------------------------------------------------------')
pt.legend(prop={'family':'Times New Roman', 'size':20})
pt.axis([0,35,0,0.25])
pt.xticks(range(0,35,1), [str(n) for n in range(0,35,1)])
pt.grid(True)
pt.savefig('success_distribution_BS.pdf',dpi=300, bbox_inches='tight')
pt.show()
# Out:
# Success probability evts: 0.090356
# -----------------------------------------------------------
# P0w= 0.819465;Hist[0]= 0.165171
# PB2= 0.899819
# PS1= 0.100488
# PB*PS= 0.090421
# rt1 = 14.996983 B/s
# P(At least 1 beacon during Tw)= 0.834829
# -----------------------------------------------------------
# Success probability evts: 0.159926
# -----------------------------------------------------------
# P0w= 0.680063;Hist[0]= 0.027024
# PB2= 0.800101
# PS1= 0.199995
# PB*PS= 0.160016
# rt1 = 13.335009 B/s
# P(At least 1 beacon during Tw)= 0.972976
# -----------------------------------------------------------
# Success probability evts: 0.209145
# -----------------------------------------------------------
# P0w= 0.580765;Hist[0]= 0.003866
# PB2= 0.700739
# PS1= 0.298831
# PB*PS= 0.209402
# rt1 = 11.678979 B/s
# P(At least 1 beacon during Tw)= 0.996134
# -----------------------------------------------------------
# Success probability evts: 0.239106
# -----------------------------------------------------------
# P0w= 0.520123;Hist[0]= 0.000655
# PB2= 0.600075
# PS1= 0.399458
# PB*PS= 0.239705
# rt1 = 10.001243 B/s
# P(At least 1 beacon during Tw)= 0.999345
# -----------------------------------------------------------
# Success probability evts: 0.250105
# -----------------------------------------------------------
# P0w= 0.500000;Hist[0]= 0.001172
# PB2= 0.500114
# PS1= 0.500431
# PB*PS= 0.250273
# rt1 = 8.335240 B/s
# P(At least 1 beacon during Tw)= 0.998828
# -----------------------------------------------------------
# Success probability evts: 0.239731
# -----------------------------------------------------------
# P0w= 0.519973;Hist[0]= 0.000192
# PB2= 0.399778
# PS1= 0.599643
# PB*PS= 0.239724
# rt1 = 6.662958 B/s
# P(At least 1 beacon during Tw)= 0.999808
# -----------------------------------------------------------
# Success probability evts: 0.210189
# -----------------------------------------------------------
# P0w= 0.579715;Hist[0]= 0.000717
# PB2= 0.300462
# PS1= 0.699748
# PB*PS= 0.210247
# rt1 = 5.007693 B/s
# P(At least 1 beacon during Tw)= 0.999283
# -----------------------------------------------------------
# Success probability evts: 0.159377
# -----------------------------------------------------------
# P0w= 0.680122;Hist[0]= 0.001520
# PB2= 0.199610
# PS1= 0.799814
# PB*PS= 0.159651
# rt1 = 3.326835 B/s
# P(At least 1 beacon during Tw)= 0.998480
# -----------------------------------------------------------
# Success probability evts: 0.089808
# -----------------------------------------------------------
# P0w= 0.820251;Hist[0]= 0.022767
# PB2= 0.099848
# PS1= 0.900161
# PB*PS= 0.089879
# rt1 = 1.664128 B/s
# P(At least 1 beacon during Tw)= 0.977233
# -----------------------------------------------------------
# [0.17712641]
# -----------------------------------------------------------

# %% [markdown]
# ## Networking enabled

# %%
for i in range(1,10):
    
    f3 = open("r2%d-d0-result.txt"%i)
    raw3 = f3.read()
    f3.close()

    f4 = open("r2%d-d1-result.txt"%i)
    raw4 = f4.read()
    f4.close()
    
    Eb3,Es3,En3 = computeEvents(raw3,Ttx,Trx,Tn)
    Eb4,Es4,En4 = computeEvents(raw4,Ttx,Trx,Tn)
    wnds2 = genWindowHistogram(raw3,raw4,1000,Trx)
    Ps = checkSuccess(raw4,raw3)*Ttx/(Eb3*Ttx+En3*Tn+Es3*Trx)
    print("Success probability evts: %.6f"%(Ps))
    print('-----------------------------------------------------------')
    Ps1 = Es3*Trx/(Eb3*Ttx+En3*Tn+Es3*Trx)
    Pb2 = Eb4*Ttx/(Eb4*Ttx+En4*Tn+Es4*Trx)
    rt1 = Pb2/(Trx/1000)
    print("PB2= %.6f"%(Pb2))
    print("PS1= %.6f"%(Ps1))
    print("PB*PS= %.6f"%(Pb2*Ps1))
    print('-----------------------------------------------------------')
    pt.plot(range(len(wnds2)),wnds2,label=r"$P_{S}$: %.6f"%(Trx*Es3/len(raw3)))

    
pt.legend()
pt.axis([0,35,0,0.25])
pt.xticks(range(0,35,1), [str(n) for n in range(0,35,1)])
pt.grid(True)
pt.savefig('success_distribution_BSN.pdf',dpi=300, bbox_inches='tight')
pt.show()

# %% [markdown]
#     Probability of failure

# %%
Pb = 0.5
Ps = 0.5
Tw = 1000
Tb = 23
Ts = 60
P0b = e**(-Pb*Tw/Tb)
P0s = e**(-Ps*Tw/Ts)
Pfail = Ps*(1-Pb) + Pb*(1-Ps) + (1-Pb)*(1-Ps)
print(P0b+P0s+P0b*P0s)
print(P0b)
print(P0s)
print(Pfail)
